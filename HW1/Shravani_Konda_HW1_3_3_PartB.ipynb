# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import math

def get_data_loaders(train_batch_size, test_batch_size):
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    ])

    trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
    temp = torch.tensor(np.random.randint(0, 10, (len(trainset),)))
    trainset.targets = temp.tolist()
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=train_batch_size, shuffle=True)

    testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
    testloader = torch.utils.data.DataLoader(testset, batch_size=test_batch_size, shuffle=False)

    return trainloader, testloader

# %%
class CNN_Model(nn.Module):
    def __init__(self):
        super(CNN_Model, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(16)
        self.fc1 = nn.Linear(16 * 16 * 16, 120)  
        self.fc2 = nn.Linear(120, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = self.bn1(x)
        x = x.view(-1, 16 * 16 * 16)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def compute_sensitivity(inputs, model, loss_func):
    inputs.requires_grad_()
    outputs = model(inputs)
    loss = loss_func(outputs, outputs.max(1)[1])  
    loss.backward()
    sensitivity = torch.sqrt(torch.sum(inputs.grad ** 2))
    return sensitivity.item()

def train_and_evaluate_model(model, train_loader, test_loader, optimizer, criterion, epochs=10):
    model.train()
    train_losses, test_losses, train_accuracies, test_accuracies, sensitivities = [], [], [], [], []

    for epoch in range(epochs):
        total_train_loss = 0.0
        actual_train = 0
        total_train = 0
        sensitivity_collected = 0.0
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            
            sensitivity = compute_sensitivity(inputs, model, criterion)
            sensitivity_collected += sensitivity
            
            optimizer.step()
            
            total_train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            actual_train += (predicted == labels).sum().item()
            
        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        train_accuracy = 100 * actual_train / total_train
        train_accuracies.append(train_accuracy)
        epoch_sensitivity = sensitivity_collected / len(train_loader)
        sensitivities.append(epoch_sensitivity)

        model.eval()
        total_test_loss = 0.0
        total_correct = 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                outputs = model(inputs)
                total_test_loss += criterion(outputs, labels).item()
                preds = outputs.argmax(dim=1, keepdim=True)
                total_correct += preds.eq(labels.view_as(preds)).sum().item()

        avg_test_loss = total_test_loss / len(test_loader)
        test_losses.append(avg_test_loss)
        test_accuracy = 100. * total_correct / len(test_loader.dataset)
        test_accuracies.append(test_accuracy)

        print(f'Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}, Test Loss: {avg_test_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Accuracy: {test_accuracy:.4f}, Sensitivity: {epoch_sensitivity:.4f}')

    return train_losses, test_losses, train_accuracies, test_accuracies, sensitivities

# %%
model_parameters = [
    (64, optim.Adam, 0.001),
    (128, optim.SGD, 0.01),
    (256, optim.Adam, 0.01),
    (64, optim.SGD, 0.001),
    (128, optim.Adam, 0.01)
]

all_train_losses, all_test_losses = [], []
all_train_accuracies, all_test_accuracies = [], []
all_sensitivities = []

epochs = 10

for batch_size, optimizer_type, learning_rate in model_parameters:
    train_loader, test_loader = get_data_loaders(batch_size, 64)

    model = CNN_Model()
    optimizer = optimizer_type(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    train_losses, test_losses, train_accuracies, test_accuracies, sensitivities = train_and_evaluate_model(model, train_loader, test_loader, optimizer, criterion, epochs)

    all_train_losses.append(train_losses)
    all_test_losses.append(test_losses)
    all_train_accuracies.append(train_accuracies)
    all_test_accuracies.append(test_accuracies)
    all_sensitivities.append(sensitivities)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1, Train Loss: 2.7895, Test Loss: 2.7685, Train Accuracy: 9.9480, Test Accuracy: 10.0000, Sensitivity: 0.0203
# Epoch 2, Train Loss: 2.7478, Test Loss: 2.8170, Train Accuracy: 9.9080, Test Accuracy: 10.0000, Sensitivity: 0.0141
# Epoch 3, Train Loss: 2.7292, Test Loss: 2.7727, Train Accuracy: 9.9160, Test Accuracy: 9.9900, Sensitivity: 0.0153
# Epoch 4, Train Loss: 2.6800, Test Loss: 2.8660, Train Accuracy: 10.2580, Test Accuracy: 10.0100, Sensitivity: 0.0203
# Epoch 5, Train Loss: 2.5682, Test Loss: 2.8810, Train Accuracy: 12.7460, Test Accuracy: 10.0200, Sensitivity: 0.0418
# Epoch 6, Train Loss: 2.4023, Test Loss: 3.0807, Train Accuracy: 17.9280, Test Accuracy: 9.9500, Sensitivity: 0.0786
# Epoch 7, Train Loss: 2.2222, Test Loss: 3.4480, Train Accuracy: 24.3360, Test Accuracy: 9.4000, Sensitivity: 0.1203
# Epoch 8, Train Loss: 2.0400, Test Loss: 3.6438, Train Accuracy: 30.4640, Test Accuracy: 9.5100, Sensitivity: 0.1553
# Epoch 9, Train Loss: 1.8809, Test Loss: 4.1224, Train Accuracy: 35.7360, Test Accuracy: 9.4000, Sensitivity: 0.1869
# Epoch 10, Train Loss: 1.7476, Test Loss: 4.5561, Train Accuracy: 40.3240, Test Accuracy: 9.4200, Sensitivity: 0.2143
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1, Train Loss: 2.7281, Test Loss: 2.7771, Train Accuracy: 10.1020, Test Accuracy: 8.6300, Sensitivity: 0.0173
# Epoch 2, Train Loss: 2.7362, Test Loss: 2.7588, Train Accuracy: 10.0600, Test Accuracy: 8.5100, Sensitivity: 0.0160
# Epoch 3, Train Loss: 2.7263, Test Loss: 2.7565, Train Accuracy: 10.1160, Test Accuracy: 8.4700, Sensitivity: 0.0162
# Epoch 4, Train Loss: 2.7164, Test Loss: 2.8151, Train Accuracy: 10.1520, Test Accuracy: 8.5400, Sensitivity: 0.0166
# Epoch 5, Train Loss: 2.7071, Test Loss: 2.7997, Train Accuracy: 10.1720, Test Accuracy: 8.5300, Sensitivity: 0.0171
# Epoch 6, Train Loss: 2.6953, Test Loss: 2.7959, Train Accuracy: 10.2440, Test Accuracy: 8.4100, Sensitivity: 0.0178
# Epoch 7, Train Loss: 2.6831, Test Loss: 2.7941, Train Accuracy: 10.2240, Test Accuracy: 8.4700, Sensitivity: 0.0184
# Epoch 8, Train Loss: 2.6686, Test Loss: 2.8337, Train Accuracy: 10.2640, Test Accuracy: 8.4900, Sensitivity: 0.0192
# Epoch 9, Train Loss: 2.6538, Test Loss: 2.8465, Train Accuracy: 10.3040, Test Accuracy: 8.5600, Sensitivity: 0.0201
# Epoch 10, Train Loss: 2.6358, Test Loss: 2.7818, Train Accuracy: 10.3380, Test Accuracy: 8.3600, Sensitivity: 0.0211
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1, Train Loss: 3.1288, Test Loss: 2.7671, Train Accuracy: 10.2020, Test Accuracy: 10.0000, Sensitivity: 0.0079
# Epoch 2, Train Loss: 2.7544, Test Loss: 2.7561, Train Accuracy: 10.2100, Test Accuracy: 10.0000, Sensitivity: 0.0034
# Epoch 3, Train Loss: 2.7487, Test Loss: 2.7675, Train Accuracy: 10.2120, Test Accuracy: 10.0000, Sensitivity: 0.0034
# Epoch 4, Train Loss: 2.7451, Test Loss: 2.7478, Train Accuracy: 10.2100, Test Accuracy: 10.0000, Sensitivity: 0.0035
# Epoch 5, Train Loss: 2.7369, Test Loss: 2.7656, Train Accuracy: 10.2280, Test Accuracy: 10.0000, Sensitivity: 0.0027
# Epoch 6, Train Loss: 2.7335, Test Loss: 2.7623, Train Accuracy: 10.2660, Test Accuracy: 10.0100, Sensitivity: 0.0022
# Epoch 7, Train Loss: 2.7171, Test Loss: 2.7793, Train Accuracy: 10.6820, Test Accuracy: 10.0800, Sensitivity: 0.0057
# Epoch 8, Train Loss: 2.6968, Test Loss: 2.8430, Train Accuracy: 11.3940, Test Accuracy: 10.3500, Sensitivity: 0.0109
# Epoch 9, Train Loss: 2.6743, Test Loss: 2.8156, Train Accuracy: 12.5540, Test Accuracy: 10.2200, Sensitivity: 0.0193
# Epoch 10, Train Loss: 2.6467, Test Loss: 2.8391, Train Accuracy: 13.6160, Test Accuracy: 10.2400, Sensitivity: 0.0244
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1, Train Loss: 2.6770, Test Loss: 2.7170, Train Accuracy: 10.1620, Test Accuracy: 10.6000, Sensitivity: 0.0255
# Epoch 2, Train Loss: 2.7332, Test Loss: 2.7365, Train Accuracy: 10.1460, Test Accuracy: 10.5900, Sensitivity: 0.0236
# Epoch 3, Train Loss: 2.7343, Test Loss: 2.7320, Train Accuracy: 10.1400, Test Accuracy: 10.6100, Sensitivity: 0.0235
# Epoch 4, Train Loss: 2.7333, Test Loss: 2.7317, Train Accuracy: 10.1520, Test Accuracy: 10.6600, Sensitivity: 0.0234
# Epoch 5, Train Loss: 2.7312, Test Loss: 2.7324, Train Accuracy: 10.1580, Test Accuracy: 10.7600, Sensitivity: 0.0233
# Epoch 6, Train Loss: 2.7292, Test Loss: 2.7297, Train Accuracy: 10.1700, Test Accuracy: 10.8100, Sensitivity: 0.0233
# Epoch 7, Train Loss: 2.7266, Test Loss: 2.7286, Train Accuracy: 10.1800, Test Accuracy: 10.8600, Sensitivity: 0.0232
# Epoch 8, Train Loss: 2.7250, Test Loss: 2.7200, Train Accuracy: 10.1760, Test Accuracy: 10.7900, Sensitivity: 0.0232
# Epoch 9, Train Loss: 2.7216, Test Loss: 2.7299, Train Accuracy: 10.1760, Test Accuracy: 10.8500, Sensitivity: 0.0232
# Epoch 10, Train Loss: 2.7200, Test Loss: 2.7291, Train Accuracy: 10.1780, Test Accuracy: 10.8500, Sensitivity: 0.0232
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1, Train Loss: 2.9436, Test Loss: 2.7719, Train Accuracy: 9.7900, Test Accuracy: 10.0000, Sensitivity: 0.0078
# Epoch 2, Train Loss: 2.7566, Test Loss: 2.7174, Train Accuracy: 9.8240, Test Accuracy: 10.0000, Sensitivity: 0.0040
# Epoch 3, Train Loss: 2.7549, Test Loss: 2.7585, Train Accuracy: 9.8240, Test Accuracy: 10.0000, Sensitivity: 0.0018
# Epoch 4, Train Loss: 2.7586, Test Loss: 2.7418, Train Accuracy: 9.8220, Test Accuracy: 10.0000, Sensitivity: 0.0005
# Epoch 5, Train Loss: 2.7575, Test Loss: 2.7766, Train Accuracy: 9.8380, Test Accuracy: 10.0000, Sensitivity: 0.0007
# Epoch 6, Train Loss: 2.7588, Test Loss: 2.7484, Train Accuracy: 9.8480, Test Accuracy: 10.0000, Sensitivity: 0.0009
# Epoch 7, Train Loss: 2.7576, Test Loss: 2.7608, Train Accuracy: 9.8620, Test Accuracy: 10.0000, Sensitivity: 0.0010
# Epoch 8, Train Loss: 2.7593, Test Loss: 2.7526, Train Accuracy: 9.8340, Test Accuracy: 10.0000, Sensitivity: 0.0003
# Epoch 9, Train Loss: 2.7589, Test Loss: 2.7589, Train Accuracy: 9.8240, Test Accuracy: 10.0000, Sensitivity: 0.0001
# Epoch 10, Train Loss: 2.7596, Test Loss: 2.7481, Train Accuracy: 9.8420, Test Accuracy: 10.0000, Sensitivity: 0.0004

# %%
def plot_metrics(train_metrics, test_metrics, metric_name, metric_label, title):
    plt.figure(figsize=(10, 5))
    for i, (train_metric, test_metric) in enumerate(zip(train_metrics, test_metrics)):
        plt.plot(range(1, len(train_metric) + 1), train_metric, label=f'Train {metric_label} ({i + 1})')
        plt.plot(range(1, len(test_metric) + 1), test_metric, label=f'Test {metric_label} ({i + 1})')

    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel(metric_name)
    plt.legend()
    plt.grid(True)
    plt.show()

plot_metrics(all_train_losses, all_test_losses, 'Loss', 'Loss', 'Training and Testing Loss')

plot_metrics(all_train_accuracies, all_test_accuracies, 'Accuracy (%)', 'Accuracy', 'Training and Testing Accuracy')

plt.figure(figsize=(10, 5))
for i, sensitivity in enumerate(all_sensitivities):
    plt.plot(range(1, len(sensitivity) + 1), sensitivity, label=f'Sensitivity ({i + 1})')

plt.title('Sensitivity')
plt.xlabel('Epoch')
plt.ylabel('Sensitivity')
plt.legend()
plt.grid(True)
plt.show()

# %%
def plot_model_metrics(train_losses, test_losses, train_accuracies, test_accuracies, sensitivities, model_labels):
    num_models = len(model_labels)
    
    for i in range(num_models):
        plt.figure(figsize=(3, 3))
        
        plt.plot(range(1, len(train_losses[i]) + 1), train_losses[i], label=f'Train Loss')
        plt.plot(range(1, len(test_losses[i]) + 1), test_losses[i], label=f'Test Loss')
        plt.plot(range(1, len(sensitivities[i]) + 1), sensitivities[i], label=f'Sensitivity')
        
        plt.title(f'{model_labels[i]}: Loss and Sensitivity')
        plt.xlabel('Epoch')
        plt.ylabel('Value')
        plt.legend()
        plt.grid(True)
        plt.show()
    
    for i in range(num_models):
        plt.figure(figsize=(3, 3))
        
        plt.plot(range(1, len(train_accuracies[i]) + 1), train_accuracies[i], label=f'Train Accuracy')
        plt.plot(range(1, len(test_accuracies[i]) + 1), test_accuracies[i], label=f'Test Accuracy')
        plt.plot(range(1, len(sensitivities[i]) + 1), sensitivities[i], label=f'Sensitivity')
        
        plt.title(f'{model_labels[i]}: Accuracy and Sensitivity')
        plt.xlabel('Epoch')
        plt.ylabel('Value')
        plt.legend()
        plt.grid(True)
        plt.show()

model_labels = ['Model 1', 'Model 2', 'Model 3', 'Model 4', 'Model 5']
plot_model_metrics(all_train_losses, all_test_losses, all_train_accuracies, all_test_accuracies, all_sensitivities, model_labels)
