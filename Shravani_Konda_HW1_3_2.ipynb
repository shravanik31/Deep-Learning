# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import numpy as np

train_batch_size = 100
test_batch_size = 64

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=train_batch_size, shuffle=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=test_batch_size, shuffle=False)

class CNN_Model(nn.Module):
    def __init__(self, num_channels, fc_size):
        super(CNN_Model, self).__init__()
        self.conv1 = nn.Conv2d(3, num_channels, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(num_channels)
        self.conv2 = nn.Conv2d(num_channels, num_channels * 2, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(num_channels * 2)
        self.conv3 = nn.Conv2d(num_channels * 2, num_channels * 4, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(num_channels * 4)
        
        dummy_input = torch.randn(1, 3, 32, 32)
        dummy_output = self._forward_features(dummy_input)
        num_features = dummy_output.view(dummy_output.size(0), -1).size(1)
        
        self.fc1 = nn.Linear(num_features, fc_size)
        self.fc2 = nn.Linear(fc_size, 10)

    def _forward_features(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = self.bn1(x)
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = self.bn2(x)
        x = F.relu(F.max_pool2d(self.conv3(x), 2))
        x = self.bn3(x)
        return x

    def forward(self, x):
        x = self._forward_features(x)
        x = x.view(x.size(0), -1) 
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)
    
def train_and_evaluate_model(model, train_loader, test_loader, optimizer, criterion, epochs=10):
    model.train()
    train_losses, test_losses = [], []
    train_accuracies, test_accuracies = [], []

    for epoch in range(epochs):
        total_train_loss = 0.0
        total_correct_train = 0
        total_samples_train = 0

        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

            _, predicted_train = torch.max(outputs.data, 1)
            total_samples_train += labels.size(0)
            total_correct_train += (predicted_train == labels).sum().item()

        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        train_accuracy = total_correct_train / total_samples_train
        train_accuracies.append(train_accuracy)

        model.eval()
        total_test_loss = 0.0
        total_correct_test = 0
        total_samples_test = 0

        with torch.no_grad():
            for inputs, labels in test_loader:
                outputs = model(inputs)
                total_test_loss += criterion(outputs, labels).item()

                _, predicted_test = torch.max(outputs.data, 1)
                total_samples_test += labels.size(0)
                total_correct_test += (predicted_test == labels).sum().item()

        avg_test_loss = total_test_loss / len(test_loader)
        test_losses.append(avg_test_loss)
        test_accuracy = total_correct_test / total_samples_test
        test_accuracies.append(test_accuracy)

        print(f'Model: Channels={}, FC Size={}, Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}, Test Loss: {avg_test_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Accuracy: {test_accuracy:.4f}')

    return train_losses, test_losses, train_accuracies, test_accuracies

models = []
for i in range(1, 11):
    num_channels = 16 * i
    fc_size = 120 * i
    model = CNN_Model(num_channels, fc_size)
    models.append(model)

results = []
for i, model in enumerate(models, 1):
    print(f"Training Model {i}:")
    loss_func = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    train_losses, test_losses, train_accuracies, test_accuracies = train_and_evaluate_model(model, trainloader, testloader, optimizer, loss_func)
    results.append((model.conv1.out_channels, model.fc1.out_features, train_losses, test_losses, train_accuracies, test_accuracies))

num_parameters = []
train_losses_list = []
test_losses_list = []
train_accuracies_list = []
test_accuracies_list = []

for result in results:
    num_parameters.append(result[0] * result[0] * 3 * 3 + result[1] * result[0] * 3 * 3 + result[1] + result[1] * 10)  # Calculating number of parameters
    train_losses_list.append(result[2])
    test_losses_list.append(result[3])
    train_accuracies_list.append(result[4])
    test_accuracies_list.append(result[5])

plt.figure(figsize=(8, 10))

plt.subplot(2, 1, 1)
for i in range(len(num_parameters)):
    plt.scatter(range(len(train_losses_list[i])), train_losses_list[i], label=f'{num_parameters[i]} parameters', color='blue', s=60)
    plt.scatter(range(len(test_losses_list[i])), test_losses_list[i], color='orange', s=60)

plt.title('Training and Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train Loss', 'Test Loss'])

plt.subplot(2, 1, 2)
for i in range(len(num_parameters)):
    plt.scatter(range(len(train_accuracies_list[i])), train_accuracies_list[i], label=f'{num_parameters[i]} parameters', color='green', s=60)
    plt.scatter(range(len(test_accuracies_list[i])), test_accuracies_list[i], color='red', s=60)

plt.title('Training and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train Accuracy', 'Test Accuracy'])

plt.tight_layout()
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Training Model 1:
# Model: Channels=16, FC Size=120, Epoch 1, Train Loss: 1.1452, Test Loss: 0.9393, Train Accuracy: 0.5895, Test Accuracy: 0.6641
# Model: Channels=16, FC Size=120, Epoch 2, Train Loss: 0.7909, Test Loss: 0.8829, Train Accuracy: 0.7211, Test Accuracy: 0.6944
# Model: Channels=16, FC Size=120, Epoch 3, Train Loss: 0.6429, Test Loss: 0.7806, Train Accuracy: 0.7751, Test Accuracy: 0.7324
# Model: Channels=16, FC Size=120, Epoch 4, Train Loss: 0.5346, Test Loss: 0.7769, Train Accuracy: 0.8122, Test Accuracy: 0.7391
# Model: Channels=16, FC Size=120, Epoch 5, Train Loss: 0.4401, Test Loss: 0.8190, Train Accuracy: 0.8441, Test Accuracy: 0.7349
# Model: Channels=16, FC Size=120, Epoch 6, Train Loss: 0.3638, Test Loss: 0.8711, Train Accuracy: 0.8705, Test Accuracy: 0.7335
# Model: Channels=16, FC Size=120, Epoch 7, Train Loss: 0.2963, Test Loss: 0.9175, Train Accuracy: 0.8959, Test Accuracy: 0.7409
# Model: Channels=16, FC Size=120, Epoch 8, Train Loss: 0.2500, Test Loss: 1.0243, Train Accuracy: 0.9119, Test Accuracy: 0.7278
# Model: Channels=16, FC Size=120, Epoch 9, Train Loss: 0.2045, Test Loss: 1.1446, Train Accuracy: 0.9271, Test Accuracy: 0.7323
# Model: Channels=16, FC Size=120, Epoch 10, Train Loss: 0.1717, Test Loss: 1.2685, Train Accuracy: 0.9393, Test Accuracy: 0.7217
# Training Model 2:
# Model: Channels=32, FC Size=240, Epoch 1, Train Loss: 1.0384, Test Loss: 0.8251, Train Accuracy: 0.6294, Test Accuracy: 0.7070
# Model: Channels=32, FC Size=240, Epoch 2, Train Loss: 0.6779, Test Loss: 0.7286, Train Accuracy: 0.7636, Test Accuracy: 0.7490
# Model: Channels=32, FC Size=240, Epoch 3, Train Loss: 0.4955, Test Loss: 0.7479, Train Accuracy: 0.8264, Test Accuracy: 0.7537
# Model: Channels=32, FC Size=240, Epoch 4, Train Loss: 0.3502, Test Loss: 0.7737, Train Accuracy: 0.8758, Test Accuracy: 0.7616
# Model: Channels=32, FC Size=240, Epoch 5, Train Loss: 0.2479, Test Loss: 0.9098, Train Accuracy: 0.9113, Test Accuracy: 0.7578
# Model: Channels=32, FC Size=240, Epoch 6, Train Loss: 0.1777, Test Loss: 0.9217, Train Accuracy: 0.9375, Test Accuracy: 0.7663
# Model: Channels=32, FC Size=240, Epoch 7, Train Loss: 0.1446, Test Loss: 1.0322, Train Accuracy: 0.9481, Test Accuracy: 0.7608
# Model: Channels=32, FC Size=240, Epoch 8, Train Loss: 0.1163, Test Loss: 1.2036, Train Accuracy: 0.9605, Test Accuracy: 0.7562
# Model: Channels=32, FC Size=240, Epoch 9, Train Loss: 0.1082, Test Loss: 1.2102, Train Accuracy: 0.9622, Test Accuracy: 0.7542
# Model: Channels=32, FC Size=240, Epoch 10, Train Loss: 0.1060, Test Loss: 1.2809, Train Accuracy: 0.9645, Test Accuracy: 0.7623
# Training Model 3:
# Model: Channels=48, FC Size=360, Epoch 1, Train Loss: 1.0434, Test Loss: 0.7904, Train Accuracy: 0.6318, Test Accuracy: 0.7221
# Model: Channels=48, FC Size=360, Epoch 2, Train Loss: 0.6638, Test Loss: 0.7100, Train Accuracy: 0.7665, Test Accuracy: 0.7546
# Model: Channels=48, FC Size=360, Epoch 3, Train Loss: 0.4634, Test Loss: 0.7287, Train Accuracy: 0.8390, Test Accuracy: 0.7599
# Model: Channels=48, FC Size=360, Epoch 4, Train Loss: 0.3159, Test Loss: 0.7719, Train Accuracy: 0.8912, Test Accuracy: 0.7732
# Model: Channels=48, FC Size=360, Epoch 5, Train Loss: 0.2065, Test Loss: 0.8796, Train Accuracy: 0.9278, Test Accuracy: 0.7656
# Model: Channels=48, FC Size=360, Epoch 6, Train Loss: 0.1602, Test Loss: 1.0184, Train Accuracy: 0.9434, Test Accuracy: 0.7698
# Model: Channels=48, FC Size=360, Epoch 7, Train Loss: 0.1267, Test Loss: 1.0249, Train Accuracy: 0.9562, Test Accuracy: 0.7788
# Model: Channels=48, FC Size=360, Epoch 8, Train Loss: 0.1104, Test Loss: 1.2268, Train Accuracy: 0.9619, Test Accuracy: 0.7604
# Model: Channels=48, FC Size=360, Epoch 9, Train Loss: 0.1114, Test Loss: 1.1752, Train Accuracy: 0.9620, Test Accuracy: 0.7812
# Model: Channels=48, FC Size=360, Epoch 10, Train Loss: 0.0868, Test Loss: 1.3495, Train Accuracy: 0.9710, Test Accuracy: 0.7708
# Training Model 4:
# Model: Channels=64, FC Size=480, Epoch 1, Train Loss: 1.0359, Test Loss: 0.8113, Train Accuracy: 0.6348, Test Accuracy: 0.7153
# Model: Channels=64, FC Size=480, Epoch 2, Train Loss: 0.6533, Test Loss: 0.7440, Train Accuracy: 0.7721, Test Accuracy: 0.7418
# Model: Channels=64, FC Size=480, Epoch 3, Train Loss: 0.4500, Test Loss: 0.7266, Train Accuracy: 0.8439, Test Accuracy: 0.7703
# Model: Channels=64, FC Size=480, Epoch 4, Train Loss: 0.2959, Test Loss: 0.7646, Train Accuracy: 0.8972, Test Accuracy: 0.7824
# Model: Channels=64, FC Size=480, Epoch 5, Train Loss: 0.1918, Test Loss: 0.9481, Train Accuracy: 0.9335, Test Accuracy: 0.7798
# Model: Channels=64, FC Size=480, Epoch 6, Train Loss: 0.1458, Test Loss: 0.9472, Train Accuracy: 0.9493, Test Accuracy: 0.7772
# Model: Channels=64, FC Size=480, Epoch 7, Train Loss: 0.1268, Test Loss: 0.9999, Train Accuracy: 0.9570, Test Accuracy: 0.7763
# Model: Channels=64, FC Size=480, Epoch 8, Train Loss: 0.1147, Test Loss: 1.1191, Train Accuracy: 0.9621, Test Accuracy: 0.7800
# Model: Channels=64, FC Size=480, Epoch 9, Train Loss: 0.0988, Test Loss: 1.2258, Train Accuracy: 0.9676, Test Accuracy: 0.7776
# Model: Channels=64, FC Size=480, Epoch 10, Train Loss: 0.0828, Test Loss: 1.3591, Train Accuracy: 0.9722, Test Accuracy: 0.7700
# Training Model 5:
# Model: Channels=80, FC Size=600, Epoch 1, Train Loss: 1.0620, Test Loss: 0.8406, Train Accuracy: 0.6286, Test Accuracy: 0.7053
# Model: Channels=80, FC Size=600, Epoch 2, Train Loss: 0.6644, Test Loss: 0.7052, Train Accuracy: 0.7714, Test Accuracy: 0.7583
# Model: Channels=80, FC Size=600, Epoch 3, Train Loss: 0.4498, Test Loss: 0.6742, Train Accuracy: 0.8454, Test Accuracy: 0.7792
# Model: Channels=80, FC Size=600, Epoch 4, Train Loss: 0.2853, Test Loss: 0.7957, Train Accuracy: 0.8999, Test Accuracy: 0.7799
# Model: Channels=80, FC Size=600, Epoch 5, Train Loss: 0.1988, Test Loss: 0.8771, Train Accuracy: 0.9321, Test Accuracy: 0.7639
# Model: Channels=80, FC Size=600, Epoch 6, Train Loss: 0.1488, Test Loss: 1.0287, Train Accuracy: 0.9488, Test Accuracy: 0.7706
# Model: Channels=80, FC Size=600, Epoch 7, Train Loss: 0.1285, Test Loss: 1.0091, Train Accuracy: 0.9565, Test Accuracy: 0.7798
# Model: Channels=80, FC Size=600, Epoch 8, Train Loss: 0.1078, Test Loss: 1.1838, Train Accuracy: 0.9642, Test Accuracy: 0.7814
# Model: Channels=80, FC Size=600, Epoch 9, Train Loss: 0.0990, Test Loss: 1.0930, Train Accuracy: 0.9679, Test Accuracy: 0.7853
# Model: Channels=80, FC Size=600, Epoch 10, Train Loss: 0.0960, Test Loss: 1.3394, Train Accuracy: 0.9697, Test Accuracy: 0.7730
# Training Model 6:
# Model: Channels=96, FC Size=720, Epoch 1, Train Loss: 1.0744, Test Loss: 0.8217, Train Accuracy: 0.6248, Test Accuracy: 0.7182
# Model: Channels=96, FC Size=720, Epoch 2, Train Loss: 0.6637, Test Loss: 0.7201, Train Accuracy: 0.7700, Test Accuracy: 0.7589
# Model: Channels=96, FC Size=720, Epoch 3, Train Loss: 0.4643, Test Loss: 0.7311, Train Accuracy: 0.8391, Test Accuracy: 0.7704
# Model: Channels=96, FC Size=720, Epoch 4, Train Loss: 0.3007, Test Loss: 0.8026, Train Accuracy: 0.8976, Test Accuracy: 0.7812
# Model: Channels=96, FC Size=720, Epoch 5, Train Loss: 0.2098, Test Loss: 0.9195, Train Accuracy: 0.9277, Test Accuracy: 0.7763
# Model: Channels=96, FC Size=720, Epoch 6, Train Loss: 0.1608, Test Loss: 1.0121, Train Accuracy: 0.9463, Test Accuracy: 0.7816
# Model: Channels=96, FC Size=720, Epoch 7, Train Loss: 0.1305, Test Loss: 1.0852, Train Accuracy: 0.9570, Test Accuracy: 0.7752
# Model: Channels=96, FC Size=720, Epoch 8, Train Loss: 0.1056, Test Loss: 1.0746, Train Accuracy: 0.9655, Test Accuracy: 0.7749
# Model: Channels=96, FC Size=720, Epoch 9, Train Loss: 0.1179, Test Loss: 1.1304, Train Accuracy: 0.9629, Test Accuracy: 0.7860
# Model: Channels=96, FC Size=720, Epoch 10, Train Loss: 0.0980, Test Loss: 1.3249, Train Accuracy: 0.9686, Test Accuracy: 0.7757
# Training Model 7:
# Model: Channels=112, FC Size=840, Epoch 1, Train Loss: 1.1402, Test Loss: 0.8225, Train Accuracy: 0.6065, Test Accuracy: 0.7120
# Model: Channels=112, FC Size=840, Epoch 2, Train Loss: 0.6996, Test Loss: 0.7274, Train Accuracy: 0.7563, Test Accuracy: 0.7553
# Model: Channels=112, FC Size=840, Epoch 3, Train Loss: 0.4855, Test Loss: 0.7267, Train Accuracy: 0.8328, Test Accuracy: 0.7722
# Model: Channels=112, FC Size=840, Epoch 4, Train Loss: 0.3218, Test Loss: 0.8190, Train Accuracy: 0.8891, Test Accuracy: 0.7675
# Model: Channels=112, FC Size=840, Epoch 5, Train Loss: 0.2164, Test Loss: 0.8651, Train Accuracy: 0.9251, Test Accuracy: 0.7823
# Model: Channels=112, FC Size=840, Epoch 6, Train Loss: 0.1674, Test Loss: 0.9596, Train Accuracy: 0.9432, Test Accuracy: 0.7761
# Model: Channels=112, FC Size=840, Epoch 7, Train Loss: 0.1316, Test Loss: 1.0893, Train Accuracy: 0.9567, Test Accuracy: 0.7944
# Model: Channels=112, FC Size=840, Epoch 8, Train Loss: 0.1199, Test Loss: 1.1111, Train Accuracy: 0.9606, Test Accuracy: 0.7732
# Model: Channels=112, FC Size=840, Epoch 9, Train Loss: 0.1106, Test Loss: 1.1856, Train Accuracy: 0.9654, Test Accuracy: 0.7802
# Model: Channels=112, FC Size=840, Epoch 10, Train Loss: 0.1056, Test Loss: 1.2272, Train Accuracy: 0.9671, Test Accuracy: 0.7862
# Training Model 8:
# Model: Channels=128, FC Size=960, Epoch 1, Train Loss: 1.1536, Test Loss: 0.9281, Train Accuracy: 0.6063, Test Accuracy: 0.6841
# Model: Channels=128, FC Size=960, Epoch 2, Train Loss: 0.6995, Test Loss: 0.7138, Train Accuracy: 0.7589, Test Accuracy: 0.7581
# Model: Channels=128, FC Size=960, Epoch 3, Train Loss: 0.4980, Test Loss: 0.6772, Train Accuracy: 0.8286, Test Accuracy: 0.7762
# Model: Channels=128, FC Size=960, Epoch 4, Train Loss: 0.3276, Test Loss: 0.8464, Train Accuracy: 0.8870, Test Accuracy: 0.7779
# Model: Channels=128, FC Size=960, Epoch 5, Train Loss: 0.2140, Test Loss: 0.9020, Train Accuracy: 0.9273, Test Accuracy: 0.7878
# Model: Channels=128, FC Size=960, Epoch 6, Train Loss: 0.1646, Test Loss: 1.0866, Train Accuracy: 0.9444, Test Accuracy: 0.7656
# Model: Channels=128, FC Size=960, Epoch 7, Train Loss: 0.1418, Test Loss: 1.0929, Train Accuracy: 0.9530, Test Accuracy: 0.7827
# Model: Channels=128, FC Size=960, Epoch 8, Train Loss: 0.1122, Test Loss: 1.1227, Train Accuracy: 0.9638, Test Accuracy: 0.7818
# Model: Channels=128, FC Size=960, Epoch 9, Train Loss: 0.1112, Test Loss: 1.3008, Train Accuracy: 0.9653, Test Accuracy: 0.7838
# Model: Channels=128, FC Size=960, Epoch 10, Train Loss: 0.1001, Test Loss: 1.1809, Train Accuracy: 0.9687, Test Accuracy: 0.7893
# Training Model 9:
# Model: Channels=144, FC Size=1080, Epoch 1, Train Loss: 1.1852, Test Loss: 0.8308, Train Accuracy: 0.6000, Test Accuracy: 0.7103
# Model: Channels=144, FC Size=1080, Epoch 2, Train Loss: 0.7205, Test Loss: 0.7105, Train Accuracy: 0.7507, Test Accuracy: 0.7545
# Model: Channels=144, FC Size=1080, Epoch 3, Train Loss: 0.5215, Test Loss: 0.7121, Train Accuracy: 0.8188, Test Accuracy: 0.7721
# Model: Channels=144, FC Size=1080, Epoch 4, Train Loss: 0.3442, Test Loss: 0.7426, Train Accuracy: 0.8815, Test Accuracy: 0.7700
# Model: Channels=144, FC Size=1080, Epoch 5, Train Loss: 0.2377, Test Loss: 0.8834, Train Accuracy: 0.9198, Test Accuracy: 0.7729
# Model: Channels=144, FC Size=1080, Epoch 6, Train Loss: 0.1809, Test Loss: 0.9082, Train Accuracy: 0.9392, Test Accuracy: 0.7802
# Model: Channels=144, FC Size=1080, Epoch 7, Train Loss: 0.1367, Test Loss: 1.1627, Train Accuracy: 0.9543, Test Accuracy: 0.7839
# Model: Channels=144, FC Size=1080, Epoch 8, Train Loss: 0.1222, Test Loss: 1.2304, Train Accuracy: 0.9609, Test Accuracy: 0.7775
# Model: Channels=144, FC Size=1080, Epoch 9, Train Loss: 0.1122, Test Loss: 1.2301, Train Accuracy: 0.9654, Test Accuracy: 0.7935
# Model: Channels=144, FC Size=1080, Epoch 10, Train Loss: 0.1070, Test Loss: 1.2338, Train Accuracy: 0.9686, Test Accuracy: 0.7816
# Training Model 10:
# Model: Channels=160, FC Size=1200, Epoch 1, Train Loss: 1.2638, Test Loss: 0.8710, Train Accuracy: 0.5843, Test Accuracy: 0.6901
# Model: Channels=160, FC Size=1200, Epoch 2, Train Loss: 0.7466, Test Loss: 0.8080, Train Accuracy: 0.7424, Test Accuracy: 0.7297
# Model: Channels=160, FC Size=1200, Epoch 3, Train Loss: 0.5429, Test Loss: 0.7464, Train Accuracy: 0.8116, Test Accuracy: 0.7439
# Model: Channels=160, FC Size=1200, Epoch 4, Train Loss: 0.3671, Test Loss: 0.8027, Train Accuracy: 0.8721, Test Accuracy: 0.7668
# Model: Channels=160, FC Size=1200, Epoch 5, Train Loss: 0.2492, Test Loss: 0.8798, Train Accuracy: 0.9138, Test Accuracy: 0.7840
# Model: Channels=160, FC Size=1200, Epoch 6, Train Loss: 0.1830, Test Loss: 0.8960, Train Accuracy: 0.9380, Test Accuracy: 0.7856
# Model: Channels=160, FC Size=1200, Epoch 7, Train Loss: 0.1579, Test Loss: 1.0678, Train Accuracy: 0.9462, Test Accuracy: 0.7894
# Model: Channels=160, FC Size=1200, Epoch 8, Train Loss: 0.1311, Test Loss: 1.1610, Train Accuracy: 0.9588, Test Accuracy: 0.7872
# Model: Channels=160, FC Size=1200, Epoch 9, Train Loss: 0.1241, Test Loss: 1.1580, Train Accuracy: 0.9602, Test Accuracy: 0.7906
# Model: Channels=160, FC Size=1200, Epoch 10, Train Loss: 0.0981, Test Loss: 1.1730, Train Accuracy: 0.9692, Test Accuracy: 0.7919
